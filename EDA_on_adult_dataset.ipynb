# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Problem statement 1_dataset/adult.csv")

# %%
df1=pd.read_csv("Problem statement 1_dataset/adult.csv")

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week         country  salary
# 0          2174             0              40   United-States   <=50K
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  country         32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.shape
# Out:
# (32561, 15)

# %%
df.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# so there is 15 columns

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# country           0
# salary            0
# dtype: int64

# %% [markdown]
# becoz null value is denoted by ?

# %%
df_obj = df.select_dtypes(['object'])
print(df_obj)
# Out:
#                workclass    education       marital-status  \
# 0              State-gov    Bachelors        Never-married
# 1       Self-emp-not-inc    Bachelors   Married-civ-spouse
# 2                Private      HS-grad             Divorced
# 3                Private         11th   Married-civ-spouse
# 4                Private    Bachelors   Married-civ-spouse
# ...                  ...          ...                  ...
# 32556            Private   Assoc-acdm   Married-civ-spouse
# 32557            Private      HS-grad   Married-civ-spouse
# 32558            Private      HS-grad              Widowed
# 32559            Private      HS-grad        Never-married
# 32560       Self-emp-inc      HS-grad   Married-civ-spouse
#
#                occupation    relationship    race      sex         country  \
# 0            Adm-clerical   Not-in-family   White     Male   United-States
# 1         Exec-managerial         Husband   White     Male   United-States
# ...

# %%
df[df_obj.columns] = df_obj.apply(lambda x:x.str.strip())

# %%
for each in df.columns:
    df[each] = df[each].replace(to_replace='?',value=np.nan)

# %%
df.head(20)
# Out:
#     age         workclass  fnlwgt     education  education-num  \
# 0    39         State-gov   77516     Bachelors             13
# 1    50  Self-emp-not-inc   83311     Bachelors             13
# 2    38           Private  215646       HS-grad              9
# 3    53           Private  234721          11th              7
# 4    28           Private  338409     Bachelors             13
# 5    37           Private  284582       Masters             14
# 6    49           Private  160187           9th              5
# 7    52  Self-emp-not-inc  209642       HS-grad              9
# 8    31           Private   45781       Masters             14
# 9    42           Private  159449     Bachelors             13
# 10   37           Private  280464  Some-college             10
# 11   30         State-gov  141297     Bachelors             13
# 12   23           Private  122272     Bachelors             13
# 13   32           Private  205019    Assoc-acdm             12
# ...

# %%
sns.heatmap(df.isnull(), cbar=False)
# Out:
# <AxesSubplot:>

# %%
df.isnull().sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education-num        0
# marital-status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# country            583
# salary               0
# dtype: int64

# %% [markdown]
# so we have so  null in workclass , occupation , country we will drop it becoz our data is so big

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# country           0
# salary            0
# dtype: int64

# %%
sns.boxplot(x=df['age'])
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(15, 12))

plt.title("Heatmap Relation")

sns.heatmap(df.corr(), annot=True, fmt='.2f');

# %%
sns.pairplot(df.select_dtypes(include=['int64','float64']))

# %%
numerical_cols = df.select_dtypes(include=['int64','float64'])
print(numerical_cols.columns)
# Out:
# Index(['age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss',
#        'hours-per-week'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'country', 'salary'],
#       dtype='object')

# %%
df['salary'].replace('<=50K', value=0, inplace=True)
df['salary'].replace('>50K', value=1, inplace=True)

# %%
print(df['workclass'].value_counts()/df['workclass'].count()*100)
plt.figure(figsize=(15,8))
sns.countplot(df['workclass'], hue=df['salary'])
# Out:
# Private             73.887673
# Self-emp-not-inc     8.285260
# Local-gov            6.852994
# State-gov            4.240435
# Self-emp-inc         3.560772
# Federal-gov          3.126451
# Without-pay          0.046416
# Name: workclass, dtype: float64
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='workclass', ylabel='count'>

# %% [markdown]
# we can drop without pay becoz it very less in number

# %%
print(df['occupation'].value_counts()/df['occupation'].count()*100)
# Out:
# Prof-specialty       13.387706
# Craft-repair         13.361183
# Exec-managerial      13.235197
# Adm-clerical         12.336715
# Sales                11.882501
# Other-service        10.649161
# Machine-op-inspct     6.518135
# Transport-moving      5.211856
# Handlers-cleaners     4.475831
# Farming-fishing       3.278960
# Tech-support          3.023672
# Protective-serv       2.135137
# Priv-house-serv       0.474106
# Armed-Forces          0.029839
# Name: occupation, dtype: float64

# %%
print(df['education'].value_counts()/df['education'].count()*100)
# Out:
# HS-grad         32.623831
# Some-college    22.140442
# Bachelors       16.723029
# Masters          5.394205
# Assoc-voc        4.333267
# 11th             3.474571
# Assoc-acdm       3.341953
# 10th             2.718653
# 7th-8th          1.846695
# Prof-school      1.796963
# 9th              1.508521
# 12th             1.249917
# Doctorate        1.243286
# 5th-6th          0.954844
# 1st-4th          0.500630
# Preschool        0.149194
# Name: education, dtype: float64

# %%
print(df['marital-status'].value_counts()/df['marital-status'].count()*100)
# Out:
# Married-civ-spouse       46.631523
# Never-married            32.245872
# Divorced                 13.971222
# Separated                 3.113189
# Widowed                   2.741861
# Married-spouse-absent     1.226709
# Married-AF-spouse         0.069624
# Name: marital-status, dtype: float64

# %%
print(df['relationship'].value_counts()/df['relationship'].count()*100)
# Out:
# Husband           41.320204
# Not-in-family     25.615012
# Own-child         14.806710
# Unmarried         10.649161
# Wife               4.661495
# Other-relative     2.947417
# Name: relationship, dtype: float64

# %%
print(df['race'].value_counts()/df['race'].count()*100)
# Out:
# White                 85.979046
# Black                  9.339566
# Asian-Pac-Islander     2.967310
# Amer-Indian-Eskimo     0.948213
# Other                  0.765864
# Name: race, dtype: float64

# %%
print(df['country'].value_counts()/df['country'].count()*100)
# Out:
# United-States                 91.187587
# Mexico                         2.022412
# Philippines                    0.623301
# Germany                        0.424375
# Puerto-Rico                    0.361382
# Canada                         0.354751
# India                          0.331543
# El-Salvador                    0.331543
# Cuba                           0.305020
# England                        0.285127
# Jamaica                        0.265234
# South                          0.235396
# China                          0.225449
# Italy                          0.225449
# Dominican-Republic             0.222134
# Vietnam                        0.212188
# Guatemala                      0.208872
# Japan                          0.195610
# Poland                         0.185664
# Columbia                       0.185664
# Iran                           0.139248
# Taiwan                         0.139248
# Haiti                          0.139248
# ...

# %% [markdown]
# we can drop whole column

# %%
dropcols = ['native']
for each in numerical_cols.columns:
    if df[each].value_counts(normalize=True).iloc[0] > 0.9:
        dropcols.append(each)
print(dropcols)
# Out:
# ['native', 'capital-gain', 'capital-loss']

# %%
df.drop['native']
df.drop['capital-gain']
df.drop['capital-loss']

# %% [markdown]
# the column education and education-num they are high correlated so we can drop one of them

# %%
df.drop('education',inplace=True,axis=1)

# %%
df.drop('fnlwgt',inplace=True,axis=1)

# %% [markdown]
# in race columns we see that only white in majority and other so we place other as others

# %%
to_replace = list(df['race'].unique())
to_replace.remove('White')
df.replace(to_replace,'Other',inplace=True)
df['race'].value_counts(normalize=True)*100
# Out:
# White    85.979046
# Other    14.020954
# Name: race, dtype: float64

# %% [markdown]
# we will do all this for other columns which have diff feature also

# %%
to_replace = list(df['workclass'].unique())
to_replace.remove('Private')

df.replace(to_replace,'Non_private',inplace=True)
df['workclass'].value_counts(normalize=True)*100
# Out:
# Private        73.887673
# Non_private    26.112327
# Name: workclass, dtype: float64

# %% [markdown]
# so other than private i made  Non_private

# %%
to_replace = list(df['marital-status'].unique())
to_replace.remove('Never-married')
df.replace('Never-married','Single',inplace=True)
df.replace(to_replace,'Married',inplace=True)
df['marital-status'].value_counts(normalize=True)*100
# Out:
# Married    67.754128
# Single     32.245872
# Name: marital-status, dtype: float64

# %% [markdown]
# there is category of divorce or unmarried or etc so i made them single category

# %%
df.head(10)
# Out:
#    age    workclass  education-num marital-status         occupation  \
# 0   39  Non_private             13         Single       Adm-clerical
# 1   50  Non_private             13        Married    Exec-managerial
# 2   38      Private              9        Married  Handlers-cleaners
# 3   53      Private              7        Married  Handlers-cleaners
# 4   28      Private             13        Married     Prof-specialty
# 5   37      Private             14        Married    Exec-managerial
# 6   49      Private              5        Married      Other-service
# 7   52  Non_private              9        Married    Exec-managerial
# 8   31      Private             14         Single     Prof-specialty
# 9   42      Private             13        Married    Exec-managerial
#
#     relationship   race     sex  capital-gain  capital-loss  hours-per-week  \
# 0  Not-in-family  White    Male          2174             0              40
# ...

# %%
df.drop('country',inplace=True,axis=1)
df.drop('capital-gain',inplace=True,axis=1)
df.drop('capital-loss',inplace=True,axis=1)

# %%
df.head()
# Out:
#    age    workclass  education-num marital-status         occupation  \
# 0   39  Non_private             13         Single       Adm-clerical
# 1   50  Non_private             13        Married    Exec-managerial
# 2   38      Private              9        Married  Handlers-cleaners
# 3   53      Private              7        Married  Handlers-cleaners
# 4   28      Private             13        Married     Prof-specialty
#
#     relationship   race     sex  hours-per-week  salary
# 0  Not-in-family  White    Male              40       0
# 1        Husband  White    Male              13       0
# 2  Not-in-family  White    Male              40       0
# 3        Husband  Other    Male              40       0
# 4           Wife  Other  Female              40       0

# %%
df.replace({"Private": 0, "Non_private":1}, inplace = True)

# %% [markdown]
# for "Private": 0, "Non_private":1

# %%
df.replace({"Single": 0, "Married":1}, inplace = True)

# %%
df.replace({"White": 0, "Other":1}, inplace = True)

# %%
df.replace({"Male": 0, "Female":1}, inplace = True)

# %%
df.head()
# Out:
#    age  workclass  education-num  marital-status         occupation  \
# 0   39          1             13               0       Adm-clerical
# 1   50          1             13               1    Exec-managerial
# 2   38          0              9               1  Handlers-cleaners
# 3   53          0              7               1  Handlers-cleaners
# 4   28          0             13               1     Prof-specialty
#
#     relationship  race  sex  hours-per-week  salary
# 0  Not-in-family     0    0              40       0
# 1        Husband     0    0              13       0
# 2  Not-in-family     0    0              40       0
# 3        Husband     1    0              40       0
# 4           Wife     1    1              40       0

# %%
df.drop('relationship',axis=1,inplace=True)

# %%
X = df.drop('salary', axis=1)
y = df['salary']

# %%
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 32556    0
# 32557    1
# 32558    0
# 32559    0
# 32560    1
# Name: salary, Length: 30162, dtype: int64

# %%
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder(sparse=False)
X = ohe.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
regression=LogisticRegression()

# %%
from sklearn.model_selection import GridSearchCV

parameter={'C':[0.5,1,2,3,5,6,7,9,10,30,45],'penalty':['l1','l2','elasticnet']}
log_regressor=GridSearchCV(regression,parameter,scoring='accuracy',cv=5)

log_regressor.fit(X,y)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
print(log_regressor.best_params_)
# Out:
# {'C': 1, 'penalty': 'l2'}

# %%
regression=LogisticRegression(penalty='l2',C=1.0)

# %%
regression.fit(x_train,y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
prediction=regression.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,precision_recall_curve,roc_auc_score,f1_score

# %%
confusion_matrix(y_test,prediction)
# Out:
# array([[6874,  566],
#        [1281, 1233]], dtype=int64)

# %%
accuracy_score(y_test,prediction)
# Out:
# 0.81444645368696

# %%
#decision tree
import pandas as pd
import numpy as np
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import sklearn
from sklearn.model_selection import train_test_split , GridSearchCV
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
classifier=DecisionTreeClassifier(max_depth=3)
classifier.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
param_grid = { 
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth' : [2,3,4,5,6,7,8],
    'criterion' :['gini', 'entropy']
}

# %%
CV_dt = GridSearchCV(estimator=classifier, param_grid=param_grid, cv= 5)
CV_dt.fit(x_train, y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\tree\_classes.py:298: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\tree\_classes.py:298: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\tree\_classes.py:298: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\tree\_classes.py:298: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
# ...

# %%
CV_dt.best_estimator_
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=7, max_features='auto')

# %%
classifier=DecisionTreeClassifier(criterion='entropy', max_depth=7, max_features='auto')

# %%
classifier.fit(x_train,y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\tree\_classes.py:298: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# DecisionTreeClassifier(criterion='entropy', max_depth=7, max_features='auto')

# %%
classifier.score(x_train,y_train)
# Out:
# 0.7695467141726049

# %%
pred = classifier.predict(x_test)

# %%
confusion_matrix(y_test,pred)
# Out:
# array([[7237,  203],
#        [2145,  369]], dtype=int64)

# %%
print(accuracy_score(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# 0.7641149286718907
#               precision    recall  f1-score   support
#
#            0       0.77      0.97      0.86      7440
#            1       0.65      0.15      0.24      2514
#
#     accuracy                           0.76      9954
#    macro avg       0.71      0.56      0.55      9954
# weighted avg       0.74      0.76      0.70      9954

# %%
from sklearn.ensemble import RandomForestClassifier
classifier=RandomForestClassifier()
classifier.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
param_grid = { 
    'n_estimators': [200, 500],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth' : [4,5,6,7,8],
    'criterion' :['gini', 'entropy']
}

# %%
CV_rfc = GridSearchCV(estimator=classifier, param_grid=param_grid, cv= 5)
CV_rfc.fit(x_train, y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# ...

# %%
CV_rfc.best_estimator_
# Out:
# RandomForestClassifier(max_depth=8, n_estimators=500)

# %%
rf=RandomForestClassifier(max_depth=8, n_estimators=500)

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=8, n_estimators=500)

# %%
rf.score(x_train,y_train)
# Out:
# 0.7973574821852731

# %%
y_pred=classifier.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[6679  761]
#  [1290 1224]]
# 0.7939521800281294
#               precision    recall  f1-score   support
#
#            0       0.84      0.90      0.87      7440
#            1       0.62      0.49      0.54      2514
#
#     accuracy                           0.79      9954
#    macro avg       0.73      0.69      0.71      9954
# weighted avg       0.78      0.79      0.79      9954
